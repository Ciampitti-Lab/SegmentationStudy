# %%
import sys
sys.path.append('../')

from utils.modules.SegformerEncoder import mix_transformer
from utils.modules.SegformerDecoder import segformer_head
from utils.models.SegFormer import segformer
import torch
import torch.nn as nn
import torch.nn.functional as F

# %%
x = torch.randn(1, 3, 512, 512)
model=segformer(3,1)
print(f'Original image: {x.shape}')
print(f'New image: {model.run(x).shape}')
# Out:
# Original image: torch.Size([1, 3, 512, 512])
# New image: torch.Size([1, 1, 512, 512])
