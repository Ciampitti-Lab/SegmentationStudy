# %%
# import sys
# import os, torch
# sys.path.append('../')
# os.environ.setdefault("MPLBACKEND", "Agg")

# from utils.models.wheatspikenet import wheatspikenet

# dev = "cuda" if torch.cuda.is_available() else "cpu"
# try:
#     from mmcv.ops import ModulatedDeformConv2dPack  # DCN check
#     keep_dcn = True
# except Exception:
#     keep_dcn = False

# model = wheatspikenet(device=dev, keep_dcn=keep_dcn, pretrained_backbone=False)

# x = torch.randn(1, 3, 256, 256, device=dev)
# print("Device:", dev)
# print("Original:", tuple(x.shape))

# with torch.no_grad():
#     feats = model.extract_feat(x)  # backbone+FPN feature maps

# print("After (FPN features):", [tuple(f.shape) for f in feats])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 6
#       3 sys.path.append('../')
#       4 os.environ.setdefault("MPLBACKEND", "Agg")
# ----> 6 from utils.models.wheatspikenet import wheatspikenet
#       8 dev = "cuda" if torch.cuda.is_available() else "cpu"
#       9 try:
#
# File c:\Users\Vlasis\Repos\SegmentationStudy\SegmentationStudy\notebooks\..\utils\models\wheatspikenet.py:9
#       6 import torch
#       8 from mmengine import ConfigDict
# ----> 9 from mmdet.utils import register_all_modules
#      10 from mmdet.registry import MODELS
#      13 # -------------------------- helpers -------------------------- #
#
# File c:\Users\Vlasis\miniconda3\envs\geo\Lib\site-packages\mmdet\__init__.py:2
#       1 # Copyright (c) OpenMMLab. All rights reserved.
# ----> 2 import mmcv
#       3 import mmengine
#       4 from mmengine.utils import digit_version
#
# ...
